# %%
from openpiv.piv import simple_piv
import imageio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e66b7bf2ff29> in <module>
# ----> 1 from openpiv.piv import simple_piv
#       2 import imageio
#
# ModuleNotFoundError: No module named 'openpiv'

# %%
gifurl = 'https://64.media.tumblr.com/15d6395f97f2d12e32a764c4a17be406/699471e89e1d5634-11/s500x750/eabb9c7c1ea719d4b9889d8e0217a878ed3f7a3f.gifv'

im = imageio.get_reader(gifurl)
# print(im)

images = []
for frame in im:
    images.append(frame)

for I,J in zip(images[:-1],images[1:]):
    simple_piv(I,J)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5938e0f15db0> in <module>
#       1 gifurl = 'https://64.media.tumblr.com/15d6395f97f2d12e32a764c4a17be406/699471e89e1d5634-11/s500x750/eabb9c7c1ea719d4b9889d8e0217a878ed3f7a3f.gifv'
#       2
# ----> 3 im = imageio.get_reader(gifurl)
#       4 # print(im)
#       5
#
# NameError: name 'imageio' is not defined
